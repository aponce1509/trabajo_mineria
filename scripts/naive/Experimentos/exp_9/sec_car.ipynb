# %%
import pandas as pd
import numpy as np
from parametros import *
import sys, os
sys.path.append(os.path.join(os.path.dirname(file), "..", ".."))
from prepro_py import preprocesamiento_naive
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
from sklearn.naive_bayes import CategoricalNB
os.chdir("../../../../")

# %%
to_csv = False
return_something = True
feature_selection = False
seek_correlation = None

# %%
y_data_style = "h1n1"
x_data, y_data, test = preprocesamiento_naive(
    PAHT_OUTPUT,
    features_keep=features_keep,
    features_drop=features_drop,
    y_data_style=y_data_style,
    features_NA_as_cat=features_NA_as_cat,
    imputation_method=imputation_method,
    n_estimators=n_estimators,
    criterion=criterion,
    feature_selection=feature_selection,
    seek_correlation=seek_correlation,
    to_csv=to_csv,
    return_something=return_something,
    sc_max_depth=sc_max_depth,
    print_cor=print_cor,
    value=1000,
    sampling=sampling
    )
# Out:
# Hay 26707 filas y 22440 no tienen NaN
# Hay 26708 filas y 22445 no tienen NaN

# %%
x_data.drop("respondent_id", axis=1, inplace=True)

# %%
f_selector = SFS(
    CategoricalNB(),
    k_features=23, 
    forward=True, 
    floating=False, 
    verbose=2,
    scoring='roc_auc',
    cv=5
    )
f_selector.fit(x_data, np.array(y_data).ravel())
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:   14.5s finished
#
# [2022-01-12 15:48:48] Features: 1/23 -- score: 0.7025188463654769[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed:   11.5s finished
#
# [2022-01-12 15:48:59] Features: 2/23 -- score: 0.7805626184077022[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed:   11.3s finished
#
# [2022-01-12 15:49:11] Features: 3/23 -- score: 0.8202479886053833[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:   10.8s finished
#
# [2022-01-12 15:49:22] Features: 4/23 -- score: 0.840079730100945[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:   10.9s finished
#
# [2022-01-12 15:49:33] Features: 5/23 -- score: 0.8463160282623242[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   11.2s finished
#
# [2022-01-12 15:49:44] Features: 6/23 -- score: 0.8472874051852303[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:   10.9s finished
#
# [2022-01-12 15:49:55] Features: 7/23 -- score: 0.8482457813333448[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:   10.9s finished
#
# [2022-01-12 15:50:06] Features: 8/23 -- score: 0.8485890679737604[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:   10.7s finished
#
# [2022-01-12 15:50:17] Features: 9/23 -- score: 0.8487259933111198[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:   10.5s finished
#
# [2022-01-12 15:50:27] Features: 10/23 -- score: 0.8488667076344474[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:   10.1s finished
#
# [2022-01-12 15:50:38] Features: 11/23 -- score: 0.8488821762060373[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:   10.1s finished
#
# [2022-01-12 15:50:48] Features: 12/23 -- score: 0.848891604507726[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    9.4s finished
#
# [2022-01-12 15:50:57] Features: 13/23 -- score: 0.8489475748204903[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    8.8s finished
#
# [2022-01-12 15:51:06] Features: 14/23 -- score: 0.8489170126944877[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    9.5s finished
#
# [2022-01-12 15:51:16] Features: 15/23 -- score: 0.848826877208368[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    8.3s finished
#
# [2022-01-12 15:51:24] Features: 16/23 -- score: 0.8487313729329952[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    8.2s finished
#
# [2022-01-12 15:51:33] Features: 17/23 -- score: 0.8485767500638272[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    7.8s finished
#
# [2022-01-12 15:51:40] Features: 18/23 -- score: 0.8483919167950151[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    7.7s finished
#
# [2022-01-12 15:51:48] Features: 19/23 -- score: 0.8480813241470363[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    7.3s finished
#
# [2022-01-12 15:51:56] Features: 20/23 -- score: 0.8477123816090497[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    7.2s finished
#
# [2022-01-12 15:52:03] Features: 21/23 -- score: 0.8472287702813774[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    6.6s finished
#
# [2022-01-12 15:52:10] Features: 22/23 -- score: 0.8466394942871245[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    6.4s finished
#
# [2022-01-12 15:52:16] Features: 23/23 -- score: 0.845916878535877
# SequentialFeatureSelector(estimator=CategoricalNB(), k_features=23,
#                           scoring='roc_auc', verbose=2)

# %%
values = pd.DataFrame.from_dict(f_selector.get_metric_dict()).T
values
# Out:
#                                           feature_idx  \
# 1                                               (16,)
# 2                                             (9, 16)
# 3                                         (9, 14, 16)
# 4                                     (9, 14, 15, 16)
# 5                                 (9, 14, 15, 16, 33)
# 6                             (9, 14, 15, 16, 22, 33)
# 7                         (9, 14, 15, 16, 21, 22, 33)
# 8                     (9, 14, 15, 16, 21, 22, 26, 33)
# 9                 (9, 14, 15, 16, 21, 22, 23, 26, 33)
# 10             (2, 9, 14, 15, 16, 21, 22, 23, 26, 33)
# 11         (2, 9, 14, 15, 16, 21, 22, 23, 26, 29, 33)
# 12      (2, 4, 9, 14, 15, 16, 21, 22, 23, 26, 29, 33)
# 13  (2, 4, 9, 14, 15, 16, 21, 22, 23, 26, 27, 29, 33)
# 14  (2, 4, 9, 14, 15, 16, 21, 22, 23, 26, 27, 29, ...
# 15  (2, 4, 9, 14, 15, 16, 21, 22, 23, 26, 27, 28, ...
# 16  (2, 4, 9, 14, 15, 16, 21, 22, 23, 26, 27, 28, ...
# 17  (2, 4, 9, 14, 15, 16, 20, 21, 22, 23, 26, 27, ...
# 18  (2, 4, 9, 12, 14, 15, 16, 20, 21, 22, 23, 26, ...
# 19  (2, 4, 7, 9, 12, 14, 15, 16, 20, 21, 22, 23, 2...
# 20  (2, 4, 7, 9, 12, 14, 15, 16, 20, 21, 22, 23, 2...
# 21  (2, 4, 6, 7, 9, 12, 14, 15, 16, 20, 21, 22, 23...
# 22  (2, 4, 6, 7, 9, 12, 13, 14, 15, 16, 20, 21, 22...
# 23  (2, 4, 6, 7, 9, 12, 13, 14, 15, 16, 20, 21, 22...
#
#                                             cv_scores avg_score  \
# 1   [0.7076872089626163, 0.699214441213459, 0.7037...  0.702519
# 2   [0.7862815173787342, 0.7807698308566905, 0.783...  0.780563
# 3   [0.831635442921332, 0.818610580854858, 0.81942...  0.820248
# 4   [0.8488242272947646, 0.8374628398861139, 0.843...   0.84008
# 5   [0.8559205393988831, 0.8417146166081495, 0.848...  0.846316
# 6   [0.8559933151062473, 0.8422683402636051, 0.849...  0.847287
# 7   [0.8561561442068967, 0.8439619723368541, 0.850...  0.848246
# 8   [0.856722224025617, 0.8448700456235622, 0.8503...  0.848589
# 9   [0.8568336389214954, 0.8445150677128218, 0.850...  0.848726
# 10  [0.8566978258388316, 0.8452463850368956, 0.850...  0.848867
# 11  [0.8565670389920722, 0.8456626201977195, 0.849...  0.848882
# 12  [0.8566191861895792, 0.8464091209427543, 0.850...  0.848892
# 13  [0.8566233747194993, 0.8467123705089796, 0.849...  0.848948
# 14  [0.8566037933421222, 0.8466994907794749, 0.849...  0.848917
# 15  [0.8570432748440034, 0.8468303823394823, 0.849...  0.848827
# 16  [0.856984321285376, 0.8468964563989742, 0.8489...  0.848731
# 17  [0.8563095491152255, 0.8468647282848283, 0.849...  0.848577
# 18  [0.8565248395531257, 0.847066091860744, 0.8494...  0.848392
# 19  [0.8558712194590724, 0.8470601232056076, 0.849...  0.848081
# 20  [0.8552417881253084, 0.847293633748661, 0.8489...  0.847712
# 21  [0.8543454427223769, 0.847137925148876, 0.8486...  0.847229
# 22  [0.8527117066269875, 0.8454394762662187, 0.848...  0.846639
# 23  [0.8516708569418077, 0.8450507806896206, 0.847...  0.845917
#
#                                         feature_names  ci_bound   std_dev  \
# 1                                (opinion_h1n1_risk,)  0.006273  0.004881
# 2               (doctor_recc_h1n1, opinion_h1n1_risk)  0.011066   0.00861
# 3   (doctor_recc_h1n1, health_insurance, opinion_h...  0.010979  0.008542
# 4   (doctor_recc_h1n1, health_insurance, opinion_h...  0.010916  0.008493
# 5   (doctor_recc_h1n1, health_insurance, opinion_h...  0.011524  0.008966
# 6   (doctor_recc_h1n1, health_insurance, opinion_h...  0.010935  0.008508
# 7   (doctor_recc_h1n1, health_insurance, opinion_h...   0.01067  0.008302
# 8   (doctor_recc_h1n1, health_insurance, opinion_h...  0.010818  0.008416
# 9   (doctor_recc_h1n1, health_insurance, opinion_h...  0.010791  0.008396
# 10  (behavioral_antiviral_meds, doctor_recc_h1n1, ...   0.01059  0.008239
# 11  (behavioral_antiviral_meds, doctor_recc_h1n1, ...  0.010315  0.008026
# 12  (behavioral_antiviral_meds, behavioral_face_ma...  0.010376  0.008073
# 13  (behavioral_antiviral_meds, behavioral_face_ma...  0.010248  0.007973
# 14  (behavioral_antiviral_meds, behavioral_face_ma...  0.010281  0.007999
# 15  (behavioral_antiviral_meds, behavioral_face_ma...  0.010446  0.008127
# 16  (behavioral_antiviral_meds, behavioral_face_ma...  0.010439  0.008122
# 17  (behavioral_antiviral_meds, behavioral_face_ma...  0.010437   0.00812
# 18  (behavioral_antiviral_meds, behavioral_face_ma...  0.010386  0.008081
# 19  (behavioral_antiviral_meds, behavioral_face_ma...  0.010416  0.008104
# 20  (behavioral_antiviral_meds, behavioral_face_ma...  0.010657  0.008292
# 21  (behavioral_antiviral_meds, behavioral_face_ma...  0.010777  0.008385
# 22  (behavioral_antiviral_meds, behavioral_face_ma...  0.009986  0.007769
# 23  (behavioral_antiviral_meds, behavioral_face_ma...  0.010043  0.007814
#
#      std_err
# 1    0.00244
# 2   0.004305
# 3   0.004271
# 4   0.004247
# 5   0.004483
# 6   0.004254
# 7   0.004151
# 8   0.004208
# 9   0.004198
# 10   0.00412
# 11  0.004013
# 12  0.004037
# 13  0.003986
# 14  0.003999
# 15  0.004064
# 16  0.004061
# 17   0.00406
# 18   0.00404
# 19  0.004052
# 20  0.004146
# 21  0.004192
# 22  0.003885
# 23  0.003907

# %%
fig = plot_sfs(f_selector.get_metric_dict(), kind='std_err', figsize=(15,6))

# %%
x_data.columns.values[[values.feature_idx[13]]]
# Out:
# C:\Users\ALEJAN~1\AppData\Local\Temp/ipykernel_2160/3693307271.py:1: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   x_data.columns.values[[values.feature_idx[13]]]
# array(['behavioral_antiviral_meds', 'behavioral_face_mask',
#        'doctor_recc_h1n1', 'health_insurance',
#        'opinion_h1n1_vacc_effective', 'opinion_h1n1_risk', 'age_group',
#        'education', 'race', 'marital_status', 'rent_or_own',
#        'hhs_geo_region', 'employment_industry'], dtype=object)
